# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # EDA
#
# ## Load and clean the Data:
# Missing value imputation, outlier treatment and other kinds of data redundancies
#
# Manipulation of strings and dates

# %% [markdown]
# ## After cleaning the data:
# Univariate and segmented univariate analysis is done correctly and appropriate realistic assumptions are made wherever required.
#
# (find ordered cateorical variable, )
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The analyses successfully identify at least the 5 important driver variables (i.e. variables which are strong indicators of default).

# %% [markdown]
# # code
#
# Wherever appropriate, built-in functions and standard libraries are used instead of writing long code (if-else statements, for loops, etc.).
#
# Custom functions are used to perform repetitive tasks.
#
# The code is readable with appropriately named variables and detailed comments are written wherever necessary.

# %% [markdown]
# # Plot
#
# The choice of plots for respective cases is correct

# %% [markdown]
# # presentation
#
# The presentation has a clear structure

# %% [markdown]
# # GGitHub repository
#
# The GitHub repository link contains a Python file, presentation file and a README.md file. README.md file should describe the project briefly.
